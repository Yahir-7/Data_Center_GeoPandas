# %% [markdown]
# <a href="https://colab.research.google.com/github/Yahir-7/Data_Center_GeoPandas/blob/main/Stroke.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import legend
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from shapely.geometry import box
# !pip install geodatasets
import geodatasets

# !pip install pygris
import pygris

gdp = pd.read_csv('/content/PLACES__Census_Tract_Data_(GIS_Friendly_Format),_2025_release_20260610.csv')

gdp['TractFIPS'] = pd.to_numeric(gdp['TractFIPS'], errors='coerce').fillna(0).astype(int)
gdp['TractFIPS'] = gdp['TractFIPS'].astype(str).str.zfill(11)

geo = pygris.tracts(cb=True, year=2023)

#specific rules for geoid
geo['GEOID'] = pd.to_numeric(geo['GEOID'], errors='coerce').fillna(0).astype(int)
geo['GEOID'] = geo['GEOID'].astype(str).str.zfill(11)

#merge map with your data
merged = geo.merge(gdp, left_on='GEOID', right_on='TractFIPS', how='inner')
merged

vmin = merged["STROKE_CrudePrev"].quantile(0.02)
vmax = merged["STROKE_CrudePrev"].quantile(0.98)

fig, ax = plt.subplots(figsize=(15, 9))

merged.plot(
    column="STROKE_CrudePrev",
    cmap="YlOrRd",
    linewidth=0,
    edgecolor="none",
    vmin=vmin,
    vmax=vmax,
    legend=True,
    legend_kwds={"label": "Stroke Crude Prevalence", "orientation": "vertical", 'shrink': 0.65},
    ax=ax
)
ax.set_title("US Map of Stroke Crude Prevalence by Census Tract", fontsize=20)
ax.axis("off")

ax.set_xlim(-130,-65)
ax.set_ylim(22,50)

plt.show()
# Out:
# Requirement already satisfied: geodatasets in /usr/local/lib/python3.12/dist-packages (2026.5.1)
# Requirement already satisfied: pooch in /usr/local/lib/python3.12/dist-packages (from geodatasets) (1.9.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch->geodatasets) (4.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from pooch->geodatasets) (26.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch->geodatasets) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->geodatasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->geodatasets) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->geodatasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->geodatasets) (2026.5.20)
# Requirement already satisfied: pygris in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: geopandas>=0.9 in /usr/local/lib/python3.12/dist-packages (from pygris) (1.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pygris) (2.32.4)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from pygris) (4.10.0)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.9->pygris) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.9->pygris) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.9->pygris) (26.2)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.9->pygris) (2.2.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.9->pygris) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.9->pygris) (2.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pygris) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pygris) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pygris) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pygris) (2026.5.20)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas>=0.9->pygris) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas>=0.9->pygris) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas>=0.9->pygris) (2026.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas>=0.9->pygris) (1.17.0)
# Retrieving Census tracts for the entire United States
